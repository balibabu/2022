# %% [markdown]
# # <font face='comic sans ms' color ='blue'>My Code</font>

# %% [markdown]
# ### <font face='comic sans ms' color ='sky blue'>• Write a python program to read the dataset – Use “with” python module to open and “csv.reader” to read the delimited file.</font>

# %%
import csv
with open('winequality-white.csv') as f:
    tab_reader=csv.reader(f,delimiter=';')
    columns=next(tab_reader)
    data={column:[] for column in columns}
    for row in tab_reader: 
        for i in range(len(columns)):
            data[columns[i]].append(float(row[i]))

# %%
columns.pop()
# Out:
# 'quality'

# %% [markdown]
# ### <font face='comic sans ms' color ='sky blue'>• Perform following exploratory analysis about the dataset:</font>

# %% [markdown]
# ##### <font face='comic sans ms' color ='green'>1. Group each attributes into 30 discrete buckets and plot the histogram.(Hint: For creating the required numbers of buckets use following computation to determine the bucket size:)  bucket size = (max(attr) − min(attr))/30</font>

# %%
def getBucketSize(list1):
    bucket_size=(max(list1)-min(list1))/30
    return bucket_size
bucket_sizes={}
for column in columns:
    bucket_sizes[column]=getBucketSize(data[column])

# %%
def myHistPlot(bins_size,list1,title):
    import matplotlib.pyplot as plt
    from typing import Counter
    _histogram=Counter(x//bins_size*bins_size for x in list1)
    plt.bar(_histogram.keys(),_histogram.values())
    plt.title(f'Histogram for {title}')
    plt.show()

# %%
for column in columns:
    myHistPlot(bucket_sizes[column],data[column],column)

# %%
print(bucket_sizes)
# Out:
# {'fixed acidity': 0.3466666666666666, 'volatile acidity': 0.034, 'citric acid': 0.05533333333333333, 'residual sugar': 2.1733333333333333, 'chlorides': 0.011233333333333333, 'free sulfur dioxide': 9.566666666666666, 'total sulfur dioxide': 14.366666666666667, 'density': 0.001728999999999999, 'pH': 0.03666666666666665, 'sulphates': 0.02866666666666667, 'alcohol': 0.20666666666666664}

# %% [markdown]
# ##### <font face='comic sans ms' color ='green'>2. Write a python program to compute and print the mean, median, mode and variance for each attribute.</font>

# %%
import statistics
for column in columns:
    print(f'{column}: mean={statistics.mean(data[column])}, median={statistics.median(data[column])}, mode={statistics.mode(data[column])}, variance={statistics.variance(data[column])}')
# Out:
# fixed acidity: mean=6.854787668436097, median=6.8, mode=6.8, variance=0.7121135857004642
# volatile acidity: mean=0.2782411188240098, median=0.26, mode=0.28, variance=0.010159540992172523
# citric acid: mean=0.33419150673744386, median=0.32, mode=0.3, variance=0.014645793009328216
# residual sugar: mean=6.391414863209473, median=5.2, mode=1.2, variance=25.725770164385942
# chlorides: mean=0.04577235606369947, median=0.043, mode=0.044, variance=0.00047733370982459155
# free sulfur dioxide: mean=35.30808493262556, median=34.0, mode=29.0, variance=289.2427199993196
# total sulfur dioxide: mean=138.36065741118824, median=134.0, mode=111.0, variance=1806.085490848098
# density: mean=0.994027376480196, median=0.99374, mode=0.992, variance=8.945524185781195e-06
# pH: mean=3.1882666394446715, median=3.18, mode=3.14, variance=0.02280118108410971
# sulphates: mean=0.489846876276031, median=0.47, mode=0.5, variance=0.013024705974516443
# alcohol: mean=10.514267047774602, median=10.4, mode=9.4, variance=1.5144269817873435

# %% [markdown]
# ##### <font face='comic sans ms' color ='green'>3. Write a python program to compute the “covariance” for each pair of (attribute, output label).For example; between the pairs (fixed acidity, quality), (volatile acidity, quality), and so on.Name the attributes sharing same directional relationship with the output label.</font>

# %%
def covariance(list1,list2):
    import statistics
    x_mean=statistics.mean(list1)
    y_mean=statistics.mean(list2)
    sum1=0
    for x,y in zip(list1,list2):
        sum1+=(x-x_mean)*(y-y_mean)
    return sum1/(len(list1)-1)
for column_x in columns:
    for column_y in columns: 
        cov=covariance(data[column_x],data[column_y])
        print(f'covariance of {column_x} and {column_y} is {cov}, {"share" if cov>0 else "do not share"} same directional relationship')
# Out:
# covariance of fixed acidity and fixed acidity is 0.7121135857004683, share same directional relationship
# covariance of fixed acidity and volatile acidity is -0.001930570601679208, do not share same directional relationship
# covariance of fixed acidity and citric acid is 0.02953251157178, share same directional relationship
# covariance of fixed acidity and residual sugar is 0.381021813652796, share same directional relationship
# covariance of fixed acidity and chlorides is 0.00042562553610501423, share same directional relationship
# covariance of fixed acidity and free sulfur dioxide is -0.7089186423667703, do not share same directional relationship
# covariance of fixed acidity and total sulfur dioxide is 3.2660133926297084, share same directional relationship
# covariance of fixed acidity and density is 0.0006696772557768854, share same directional relationship
# covariance of fixed acidity and pH is -0.054264825953640385, do not share same directional relationship
# covariance of fixed acidity and sulphates is -0.0016509922909276821, do not share same directional relationship
# covariance of fixed acidity and alcohol is -0.12553282191892623, do not share same directional relationship
# covariance of volatile acidity and fixed acidity is -0.001930570601679208, do not share same directional relationship
# covariance of volatile acidity and volatile acidity is 0.010159540992172346, share same directional relationship
# covariance of volatile acidity and citric acid is -0.0018232775514512708, do not share same directional relationship
# covariance of volatile acidity and residual sugar is 0.03286533368318341, share same directional relationship
# covariance of volatile acidity and chlorides is 0.00015527748570324113, share same directional relationship
# covariance of volatile acidity and free sulfur dioxide is -0.16630045911893682, do not share same directional relationship
# covariance of volatile acidity and total sulfur dioxide is 0.3823539031238291, share same directional relationship
# covariance of volatile acidity and density is 8.173932688766234e-06, share same directional relationship
# covariance of volatile acidity and pH is -0.0004857530939726634, do not share same directional relationship
# covariance of volatile acidity and sulphates is -0.00041099023093363324, do not share same directional relationship
# covariance of volatile acidity and alcohol is 0.008399723085544545, share same directional relationship
# covariance of citric acid and fixed acidity is 0.02953251157178, share same directional relationship
# covariance of citric acid and volatile acidity is -0.0018232775514512708, do not share same directional relationship
# covariance of citric acid and citric acid is 0.014645793009328724, share same directional relationship
# covariance of citric acid and residual sugar is 0.057828926456669275, share same directional relationship
# covariance of citric acid and chlorides is 0.0003023838125407895, share same directional relationship
# covariance of citric acid and free sulfur dioxide is 0.1936297766659591, share same directional relationship
# covariance of citric acid and total sulfur dioxide is 0.6229887080556078, share same directional relationship
# covariance of citric acid and density is 5.4113796377695934e-05, share same directional relationship
# covariance of citric acid and pH is -0.002992345131263866, do not share same directional relationship
# covariance of citric acid and sulphates is 0.0008608829140398371, share same directional relationship
# covariance of citric acid and alcohol is -0.011278238885878238, do not share same directional relationship
# covariance of residual sugar and fixed acidity is 0.381021813652796, share same directional relationship
# covariance of residual sugar and volatile acidity is 0.03286533368318341, share same directional relationship
# covariance of residual sugar and citric acid is 0.057828926456669275, share same directional relationship
# covariance of residual sugar and residual sugar is 25.725770164385764, share same directional relationship
# covariance of residual sugar and chlorides is 0.009827502056867178, share same directional relationship
# covariance of residual sugar and free sulfur dioxide is 25.800577899002935, share same directional relationship
# covariance of residual sugar and total sulfur dioxide is 86.53130297001056, share same directional relationship
# covariance of residual sugar and density is 0.012727165342248792, share same directional relationship
# covariance of residual sugar and pH is -0.14868366097842572, do not share same directional relationship
# covariance of residual sugar and sulphates is -0.01543474348633716, do not share same directional relationship
# covariance of residual sugar and alcohol is -2.8127403316263826, do not share same directional relationship
# covariance of chlorides and fixed acidity is 0.00042562553610501423, share same directional relationship
# covariance of chlorides and volatile acidity is 0.00015527748570324113, share same directional relationship
# covariance of chlorides and citric acid is 0.0003023838125407895, share same directional relationship
# covariance of chlorides and residual sugar is 0.009827502056867178, share same directional relationship
# covariance of chlorides and chlorides is 0.00047733370982459275, share same directional relationship
# covariance of chlorides and free sulfur dioxide is 0.03767449759033651, share same directional relationship
# covariance of chlorides and total sulfur dioxide is 0.1846874888734897, share same directional relationship
# covariance of chlorides and density is 1.6807535179787334e-05, share same directional relationship
# covariance of chlorides and pH is -0.0002983648554256058, do not share same directional relationship
# covariance of chlorides and sulphates is 4.17968689090818e-05, share same directional relationship
# covariance of chlorides and alcohol is -0.00968423502315662, do not share same directional relationship
# covariance of free sulfur dioxide and fixed acidity is -0.7089186423667703, do not share same directional relationship
# covariance of free sulfur dioxide and volatile acidity is -0.16630045911893682, do not share same directional relationship
# covariance of free sulfur dioxide and citric acid is 0.1936297766659591, share same directional relationship
# covariance of free sulfur dioxide and residual sugar is 25.800577899002935, share same directional relationship
# covariance of free sulfur dioxide and chlorides is 0.03767449759033651, share same directional relationship
# covariance of free sulfur dioxide and free sulfur dioxide is 289.24271999931875, share same directional relationship
# covariance of free sulfur dioxide and total sulfur dioxide is 444.8658909468062, share same directional relationship
# covariance of free sulfur dioxide and density is 0.014965531731955143, share same directional relationship
# covariance of free sulfur dioxide and pH is -0.0015865548135609881, do not share same directional relationship
# covariance of free sulfur dioxide and sulphates is 0.11493793418408631, share same directional relationship
# covariance of free sulfur dioxide and alcohol is -5.234508673696531, do not share same directional relationship
# covariance of total sulfur dioxide and fixed acidity is 3.2660133926297084, share same directional relationship
# covariance of total sulfur dioxide and volatile acidity is 0.3823539031238291, share same directional relationship
# covariance of total sulfur dioxide and citric acid is 0.6229887080556078, share same directional relationship
# covariance of total sulfur dioxide and residual sugar is 86.53130297001056, share same directional relationship
# covariance of total sulfur dioxide and chlorides is 0.1846874888734897, share same directional relationship
# covariance of total sulfur dioxide and free sulfur dioxide is 444.8658909468062, share same directional relationship
# covariance of total sulfur dioxide and total sulfur dioxide is 1806.085490848101, share same directional relationship
# covariance of total sulfur dioxide and density is 0.06735202561726221, share same directional relationship
# covariance of total sulfur dioxide and pH is 0.014894217157645469, share same directional relationship
# covariance of total sulfur dioxide and sulphates is 0.652644576895728, share same directional relationship
# covariance of total sulfur dioxide and alcohol is -23.47660460279631, do not share same directional relationship
# covariance of density and fixed acidity is 0.0006696772557768854, share same directional relationship
# covariance of density and volatile acidity is 8.173932688766234e-06, share same directional relationship
# covariance of density and citric acid is 5.4113796377695934e-05, share same directional relationship
# covariance of density and residual sugar is 0.012727165342248792, share same directional relationship
# covariance of density and chlorides is 1.6807535179787334e-05, share same directional relationship
# covariance of density and free sulfur dioxide is 0.014965531731955143, share same directional relationship
# covariance of density and total sulfur dioxide is 0.06735202561726221, share same directional relationship
# covariance of density and density is 8.945524185781202e-06, share same directional relationship
# covariance of density and pH is -4.226860806271924e-05, do not share same directional relationship
# covariance of density and sulphates is 2.5427472403542075e-05, share same directional relationship
# covariance of density and alcohol is -0.002871430362487792, do not share same directional relationship
# covariance of pH and fixed acidity is -0.054264825953640385, do not share same directional relationship
# covariance of pH and volatile acidity is -0.0004857530939726634, do not share same directional relationship
# covariance of pH and citric acid is -0.002992345131263866, do not share same directional relationship
# covariance of pH and residual sugar is -0.14868366097842572, do not share same directional relationship
# covariance of pH and chlorides is -0.0002983648554256058, do not share same directional relationship
# covariance of pH and free sulfur dioxide is -0.0015865548135609881, do not share same directional relationship
# covariance of pH and total sulfur dioxide is 0.014894217157645469, share same directional relationship
# covariance of pH and density is -4.226860806271924e-05, do not share same directional relationship
# covariance of pH and pH is 0.022801181084110014, share same directional relationship
# covariance of pH and sulphates is 0.0026875229690797304, share same directional relationship
# covariance of pH and alcohol is 0.022565052188878894, share same directional relationship
# covariance of sulphates and fixed acidity is -0.0016509922909276821, do not share same directional relationship
# covariance of sulphates and volatile acidity is -0.00041099023093363324, do not share same directional relationship
# covariance of sulphates and citric acid is 0.0008608829140398371, share same directional relationship
# covariance of sulphates and residual sugar is -0.01543474348633716, do not share same directional relationship
# covariance of sulphates and chlorides is 4.17968689090818e-05, share same directional relationship
# covariance of sulphates and free sulfur dioxide is 0.11493793418408631, share same directional relationship
# covariance of sulphates and total sulfur dioxide is 0.652644576895728, share same directional relationship
# covariance of sulphates and density is 2.5427472403542075e-05, share same directional relationship
# covariance of sulphates and pH is 0.0026875229690797304, share same directional relationship
# covariance of sulphates and sulphates is 0.013024705974516163, share same directional relationship
# covariance of sulphates and alcohol is -0.0024483560780414627, do not share same directional relationship
# covariance of alcohol and fixed acidity is -0.12553282191892623, do not share same directional relationship
# covariance of alcohol and volatile acidity is 0.008399723085544545, share same directional relationship
# covariance of alcohol and citric acid is -0.011278238885878238, do not share same directional relationship
# covariance of alcohol and residual sugar is -2.8127403316263826, do not share same directional relationship
# covariance of alcohol and chlorides is -0.00968423502315662, do not share same directional relationship
# covariance of alcohol and free sulfur dioxide is -5.234508673696531, do not share same directional relationship
# covariance of alcohol and total sulfur dioxide is -23.47660460279631, do not share same directional relationship
# covariance of alcohol and density is -0.002871430362487792, do not share same directional relationship
# covariance of alcohol and pH is 0.022565052188878894, share same directional relationship
# covariance of alcohol and sulphates is -0.0024483560780414627, do not share same directional relationship
# covariance of alcohol and alcohol is 1.514426981787321, share same directional relationship

# %% [markdown]
# ##### <font face='comic sans ms' color ='green'>4. Construct the “correlation matrix” for the dataset as follows:</font>

# %% [markdown]
# (a) Case I: Based on correlation between the pair of attributes. For example; between the pairs (fixed acidity, volatile acidity), (fixed acidity, citric acid), and so on.

# %%
def correlation(array1:list,array2:list)->float:
    import statistics
    cor=covariance(array1,array2)/(statistics.stdev(array1)*statistics.stdev(array2))
    return cor

correlation_matrix=[]
for column_x in columns:
    _row=[]
    for column_y in columns:
        if column_x==column_y: break
        _row.append(correlation(data[column_x],data[column_y]))
    correlation_matrix.append(_row)

# %%
print(correlation_matrix)
# Out:
# [[], [-0.022697290146647255], [0.2891806976936747, -0.14947181064857434], [0.08902070136217181, 0.06428606009099508, 0.09421162429049386], [0.023085643656347837, 0.0705115714793848, 0.1143644483868181, 0.08868453594122559], [-0.04939585908117325, -0.0970119392779604, 0.09407722101469655, 0.2990983536935192, 0.10139235214133022], [0.09106975615864112, 0.08926050355177863, 0.12113079766441845, 0.401439311159926, 0.19891029964505652, 0.6155009650098343], [0.2653310138391868, 0.027113845462434158, 0.14950257057002275, 0.8389664549045847, 0.25721132043643546, 0.2942104108843102, 0.5298813238786094], [-0.42585829099138106, -0.03191536827348861, -0.16374821140062426, -0.19413345399025578, -0.09043945597598171, -0.0006177961403311463, 0.0023209717682779003, -0.0935914934552444], [-0.017142985021137182, -0.035728146905814905, 0.06233094028523289, -0.026664365853858406, 0.016762883708175663, 0.0592172458252631, 0.13456236692980852, 0.0744931485116757, 0.15595149727965135], [-0.1208811231945332, 0.06771794277504425, -0.07572873005717912, -0.45063122203172834, -0.3601887121081628, -0.250103941483532, -0.4488921020613403, -0.7801376214255555, 0.12143209874912966, -0.017432771855951733]]

# %% [markdown]
# (b) Case II: Based on correlation between the pair (attribute, output label). For example; between the pairs (fixed acidity, quality), (volatile acidity, quality), and so on.

# %%
correlation_matrix2=[]
for column in columns:
    correlation_matrix2.append(correlation(data[column],data['quality']))

# %%
print(correlation_matrix2)
# Out:
# [-0.11366283071301805, -0.19472296892113475, -0.009209090883975443, -0.09757682889469337, -0.20993441094675974, 0.008158067123436068, -0.1747372175970634, -0.30712331273472926, 0.09942724573666428, 0.053677877132791804, 0.4355747154613729]

# %% [markdown]
# ##### <font face='comic sans ms' color ='green'>5. Answer following based on “correlation matrix” obtained from previous steps:</font>

# %% [markdown]
# (a) From Case I, name the two attributes sharing maximum similarity and dis-similarity.

# %%
x,y=0,0
x1,y1=0,0
_min=0
_max=0
for i in range(len(correlation_matrix)):
    for j in range(len(correlation_matrix[i])):
        if _max<correlation_matrix[i][j]:
            _max=correlation_matrix[i][j]
            x,y=i,j
        if _min>correlation_matrix[i][j]:
            _min=correlation_matrix[i][j]
            x1,y1=i,j
print(f'the attributes sharing maximum similarity are {columns[x]} and {columns[y]}.')
print(f'the attributes sharing maximum dis-similarity are {columns[x1]} and {columns[y1]}.')
# Out:
# the attributes sharing maximum similarity are density and residual sugar.
# the attributes sharing maximum dis-similarity are alcohol and density.

# %% [markdown]
# (b) From Case II, name the attribute sharing maximum similarity and dis-similarity with the
# output label.

# %%
x=0
x1=0
_min=correlation_matrix2[x1]
_max=correlation_matrix2[x]
for i in range(len(correlation_matrix)):
    if _max<correlation_matrix2[i]:
        _max=correlation_matrix2[i]
        x=i
    if _min>correlation_matrix2[i]:
        _min=correlation_matrix2[i]
        x1=i
print(f'the attribute sharing maximum similarity with the output label is {columns[x]}.')
print(f'the attribute sharing maximum dis-similarity with the output label is {columns[x1]}.')
# Out:
# the attribute sharing maximum similarity with the output label is alcohol.
# the attribute sharing maximum dis-similarity with the output label is density.

# %% [markdown]
# ##### <font face='comic sans ms' color ='green'>6. Construct the “scatter-plot matrix” to show between the attribute’s relationships.</font>

# %%
_size=len(columns)
fig,ax=plt.subplots(_size,_size,figsize=(20,20))
for i in range(_size):
    for j in range(_size):
        if i!=j: ax[i][j].scatter(data[columns[i]],data[columns[j]])
        else: ax[i][j].annotate(columns[i],(0.5,0.5),xycoords='axes fraction',ha='center',va='center')
plt.show()

# %% [markdown]
# # <font face='comic sans ms' color ='blue'>From Book</font>

# %%
import csv 
with open('tab_delimited_stock_prices.txt') as f: 
    tab_reader = csv.reader(f, delimiter='\t') 
    for row in tab_reader: 
        date = row[0] 
        symbol = row[1]
        closing_price = float(row[2]) 
        print(date, symbol, closing_price)

# %%
with open('colon_delimited_stock_prices.txt') as f: 
    colon_reader = csv.DictReader(f, delimiter=':') 
    for dict_row in colon_reader: 
        date = dict_row["date"] 
        symbol = dict_row["symbol"] 
        closing_price = float(dict_row["closing_price"]) 
        process(date, symbol, closing_price)

# %%
def correlation_matrix(data):
    """ Returns the len(data) x len(data) matrix whose (i, j)-th entry is the correlation between data[i] and data[j] """ 
    def correlation_ij(i: int, j: int) -> float: 
        return correlation(data[i], data[j]) 
    return make_matrix(len(data), len(data), correlation_ij)

# %% [markdown]
# # <font face='comic sans ms' color ='blue'>Testing</font>

# %%
_size=len(columns)
for i in range(_size):
    for j in range(_size):
        plt.subplot(_size,_size,(i*_size+j)+1)
        plt.scatter(data[columns[i]],data[columns[j]])
        plt.title(f'{columns[i]} vs {columns[j]}')
plt.show()

# %%
x = [0, 1, 2, 3]
y = [3, 8, 1, 10]

plt.subplot(1, 2, 1) #the figure has 1 row, 2 columns, and this plot is the first plot. 
plt.plot(x,y)
plt.title("first")
#plot 2:
x = [0, 1, 2, 3]
y = [10, 20, 30, 40]

plt.subplot(1, 2, 2) #the figure has 1 row, 2 columns, and this plot is the second plot. 
plt.plot(x,y)
plt.title("second")

plt.suptitle("MY SHOP")
plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.show()

# %%
from typing import Counter
male_age = [53,51,71,31,33,39,52,27,54,30,64,26,21,54,52,20,59,32]
histogram1=Counter(x//5*5 for x in male_age)
histogram1
# Out:
# Counter({50: 6, 70: 1, 30: 4, 35: 1, 25: 2, 60: 1, 20: 2, 55: 1})

# %%
import csv
with open('winequality-white.csv') as f:
    tab_reader=csv.reader(f,delimiter=';')
    first_row=next(tab_reader)
    print(first_row)
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
print(columns)
# Out:
# ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar', 'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol', 'quality']

# %%
len(columns)
# Out:
# 12

# %%
max([max(row) for row in correlation_matrix])
# Out:
# 1.0000000000000346

# %%
import matplotlib.pyplot as plt
_size=len(columns)
for i in range(_size):
    for j in range(_size):
        plt.subplot(_size,_size,(i*_size+j)+1)
        plt.scatter(data[columns[i]],data[columns[j]])
        # plt.title(f'{columns[i]} vs {columns[j]}')
plt.show()

# %%
a='Apple'
b=a.lower()
b
# Out:
# 'apple'
